# %%
### import necessary packages
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
### import data
data= pd.read_csv("./brca_metabric_clinical_data.tsv", sep="\t")

# %%
### feature selection

# list of featires to keep
keep_columns=["Age at Diagnosis", 
              "Cancer Type Detailed", 
              "Inferred Menopausal State", 
              "Tumor Size",
              "Lymph nodes examined positive",
              "3-Gene classifier subtype",
              "Pam50 + Claudin-low subtype",
              "Integrative Cluster",
              "Overall Survival (Months)"]

# remove other features
data = data[keep_columns].copy()

# confirm removal
print(data.columns)

# remove sapmeles where Overall Survival is na
data = data.dropna(subset=["Overall Survival (Months)"])

# check shape
print(data.shape)
# Out:
# Index(['Age at Diagnosis', 'Cancer Type Detailed', 'Inferred Menopausal State',
#        'Tumor Size', 'Lymph nodes examined positive',
#        '3-Gene classifier subtype', 'Pam50 + Claudin-low subtype',
#        'Integrative Cluster', 'Overall Survival (Months)'],
#       dtype='str')
# (1981, 9)

# %%
### group rare cancer types together

top3 = data["Cancer Type Detailed"].value_counts().nlargest(3).index

data["Cancer Type Grouped"] = data["Cancer Type Detailed"].apply(
    lambda x: x if x in top3 else "Other")

print(data["Cancer Type Grouped"].value_counts())
# Out:
# Cancer Type Grouped
# Breast Invasive Ductal Carcinoma             1538
# Breast Mixed Ductal and Lobular Carcinoma     211
# Breast Invasive Lobular Carcinoma             146
# Other                                          86
# Name: count, dtype: int64

# %%
### discretize overall survival (months) into 4 groups

for index, row in data.iterrows():
    if row["Overall Survival (Months)"]>=180:
        data.loc[index, "Survival Duration"] = "15+ years"
    elif row["Overall Survival (Months)"]>=120:
        data.loc[index, "Survival Duration"] = "10-15 years"
    elif row["Overall Survival (Months)"]>=60:
        data.loc[index, "Survival Duration"] = "5-10 years"
    else:
        data.loc[index, "Survival Duration"] = "<5 years"

# %%
### split predictors and response

predictors=["Age at Diagnosis", 
              "Cancer Type Grouped", 
              "Inferred Menopausal State", 
              "Tumor Size",
              "Lymph nodes examined positive",
              "3-Gene classifier subtype",
              "Pam50 + Claudin-low subtype",
              "Integrative Cluster"]

x= data[predictors]
y=data["Survival Duration"]

# %%
### split into test and train data 
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42)

# %%
### knn impuation

# one-hot encode
x_train = pd.get_dummies(x_train)
x_test = pd.get_dummies(x_test)
x_test = x_test.reindex(columns=x_train.columns, fill_value=0)

# scale
scaler = StandardScaler()
x_train = pd.DataFrame(
    scaler.fit_transform(x_train),
    columns=x_train.columns)

x_test = pd.DataFrame(
    scaler.transform(x_test),
    columns=x_test.columns)

# impute
imputer = KNNImputer(n_neighbors=5)

x_train = pd.DataFrame(
    imputer.fit_transform(x_train),
    columns=x_train.columns)

x_test = pd.DataFrame(
    imputer.transform(x_test),
    columns=x_test.columns)

# %%
### confirm NaNs are removed

print(x_train.isna().sum()) 
print(x_test.isna().sum())
# Out:
# Age at Diagnosis                                                 0
# Tumor Size                                                       0
# Lymph nodes examined positive                                    0
# Cancer Type Grouped_Breast Invasive Ductal Carcinoma             0
# Cancer Type Grouped_Breast Invasive Lobular Carcinoma            0
# Cancer Type Grouped_Breast Mixed Ductal and Lobular Carcinoma    0
# Cancer Type Grouped_Other                                        0
# Inferred Menopausal State_Post                                   0
# Inferred Menopausal State_Pre                                    0
# 3-Gene classifier subtype_ER+/HER2- High Prolif                  0
# 3-Gene classifier subtype_ER+/HER2- Low Prolif                   0
# 3-Gene classifier subtype_ER-/HER2-                              0
# 3-Gene classifier subtype_HER2+                                  0
# Pam50 + Claudin-low subtype_Basal                                0
# Pam50 + Claudin-low subtype_Her2                                 0
# Pam50 + Claudin-low subtype_LumA                                 0
# Pam50 + Claudin-low subtype_LumB                                 0
# Pam50 + Claudin-low subtype_NC                                   0
# Pam50 + Claudin-low subtype_Normal                               0
# Pam50 + Claudin-low subtype_claudin-low                          0
# Integrative Cluster_1                                            0
# Integrative Cluster_10                                           0
# Integrative Cluster_2                                            0
# Integrative Cluster_3                                            0
# Integrative Cluster_4ER+                                         0
# Integrative Cluster_4ER-                                         0
# Integrative Cluster_5                                            0
# Integrative Cluster_6                                            0
# Integrative Cluster_7                                            0
# Integrative Cluster_8                                            0
# Integrative Cluster_9                                            0
# dtype: int64
# Age at Diagnosis                                                 0
# Tumor Size                                                       0
# Lymph nodes examined positive                                    0
# Cancer Type Grouped_Breast Invasive Ductal Carcinoma             0
# Cancer Type Grouped_Breast Invasive Lobular Carcinoma            0
# Cancer Type Grouped_Breast Mixed Ductal and Lobular Carcinoma    0
# Cancer Type Grouped_Other                                        0
# Inferred Menopausal State_Post                                   0
# Inferred Menopausal State_Pre                                    0
# 3-Gene classifier subtype_ER+/HER2- High Prolif                  0
# 3-Gene classifier subtype_ER+/HER2- Low Prolif                   0
# 3-Gene classifier subtype_ER-/HER2-                              0
# 3-Gene classifier subtype_HER2+                                  0
# Pam50 + Claudin-low subtype_Basal                                0
# Pam50 + Claudin-low subtype_Her2                                 0
# Pam50 + Claudin-low subtype_LumA                                 0
# Pam50 + Claudin-low subtype_LumB                                 0
# Pam50 + Claudin-low subtype_NC                                   0
# Pam50 + Claudin-low subtype_Normal                               0
# Pam50 + Claudin-low subtype_claudin-low                          0
# Integrative Cluster_1                                            0
# Integrative Cluster_10                                           0
# Integrative Cluster_2                                            0
# Integrative Cluster_3                                            0
# Integrative Cluster_4ER+                                         0
# Integrative Cluster_4ER-                                         0
# Integrative Cluster_5                                            0
# Integrative Cluster_6                                            0
# Integrative Cluster_7                                            0
# Integrative Cluster_8                                            0
# Integrative Cluster_9                                            0
# dtype: int64

# %%
### seperate x train and x test for each model

# model 1- baseline
cancer_grouped_cols= [c for c in x_train.columns if c.startswith("Cancer")]
menopause_cols= [c for c in x_train.columns if c.startswith("Inferred")]

x1=["Age at Diagnosis",
    "Tumor Size",
    "Lymph nodes examined positive"] 
x1= x1 + cancer_grouped_cols + menopause_cols
x1_train= x_train[x1]
x1_test= x_test[x1]

# model 2- baseline + 3-gene
three_gene_cols = [c for c in x_train.columns if c.startswith("3-Gene")]
x2= x1 + three_gene_cols
x2_train= x_train[x2]
x2_test= x_test[x2]

# model 3- baseline + Pam 50\
Pam50_cols = [c for c in x_train.columns if c.startswith("Pam50")]
x3= x1 + Pam50_cols
x3_train= x_train[x3]
x3_test= x_test[x3]

# model 4 - baseline + integrative clusters
int_clust_cols = [c for c in x_train.columns if c.startswith("Integrative")]
x4= x1 + int_clust_cols
x4_train= x_train[x4]
x4_test= x_test[x4]

# model 5- 3-gene
x5= three_gene_cols
x5_train= x_train[x5]
x5_test= x_test[x5]

# model 6- Pam 50 
x6= Pam50_cols
x6_train= x_train[x6]
x6_test= x_test[x6]

# model 7- Integrative clusters
x7= int_clust_cols
x7_train= x_train[x7]
x7_test= x_test[x7]

# %%
### establish RandomForest models

# model 1
rf1 = RandomForestClassifier(
    n_estimators=200,
    random_state=42)

# model 2
rf2 = RandomForestClassifier(
    n_estimators=200,
    random_state=42)

# model 3
rf3 = RandomForestClassifier(
    n_estimators=200,
    random_state=42)

# model 4
rf4 = RandomForestClassifier(
    n_estimators=200,
    random_state=42)

# model 5
rf5 = RandomForestClassifier(
    n_estimators=200,
    random_state=42)

# model 6
rf6 = RandomForestClassifier(
    n_estimators=200,
    random_state=42)

# model 7
rf7 = RandomForestClassifier(
    n_estimators=200,
    random_state=42)

# %%
### fit models 

# model 1
rf1.fit(x1_train, y_train)

# model 2
rf2.fit(x2_train, y_train)

# model 3
rf3.fit(x3_train, y_train)

# model 4
rf4.fit(x4_train, y_train)

# model 5
rf5.fit(x5_train, y_train)

# model 6
rf6.fit(x6_train, y_train)

# model 7
rf7.fit(x7_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
### make predictions

# model 1
y1_pred = rf1.predict(x1_test)

# model 2
y2_pred = rf2.predict(x2_test)

# model 3
y3_pred = rf3.predict(x3_test)

# model 4
y4_pred = rf4.predict(x4_test)

# model 5
y5_pred = rf5.predict(x5_test)

# model 6
y6_pred = rf6.predict(x6_test)

# model 7
y7_pred = rf7.predict(x7_test)

# %%
### evaluate models

# model 1
print("Accuracy:", accuracy_score(y_test, y1_pred))
print(classification_report(y_test, y1_pred))

# model 2
print("Accuracy:", accuracy_score(y_test, y2_pred))
print(classification_report(y_test, y2_pred))

# model 3
print("Accuracy:", accuracy_score(y_test, y3_pred))
print(classification_report(y_test, y3_pred))

# model 4
print("Accuracy:", accuracy_score(y_test, y4_pred))
print(classification_report(y_test, y4_pred))

# model 5
print("Accuracy:", accuracy_score(y_test, y5_pred))
print(classification_report(y_test, y5_pred))

# model 6
print("Accuracy:", accuracy_score(y_test, y6_pred))
print(classification_report(y_test, y6_pred))

# model 7
print("Accuracy:", accuracy_score(y_test, y7_pred))
print(classification_report(y_test, y7_pred))
# Out:
# Accuracy: 0.2947103274559194
#               precision    recall  f1-score   support
#
#  10-15 years       0.17      0.14      0.15        86
#    15+ years       0.29      0.34      0.31       106
#   5-10 years       0.28      0.24      0.26       107
#     <5 years       0.39      0.44      0.41        98
#
#     accuracy                           0.29       397
#    macro avg       0.28      0.29      0.29       397
# weighted avg       0.29      0.29      0.29       397
#
# Accuracy: 0.3350125944584383
#               precision    recall  f1-score   support
#
#  10-15 years       0.22      0.16      0.19        86
#    15+ years       0.36      0.37      0.36       106
#   5-10 years       0.29      0.31      0.30       107
#     <5 years       0.42      0.48      0.45        98
#
#     accuracy                           0.34       397
#    macro avg       0.32      0.33      0.32       397
# weighted avg       0.33      0.34      0.33       397
#
# Accuracy: 0.32997481108312343
#               precision    recall  f1-score   support
#
#  10-15 years       0.19      0.13      0.15        86
#    15+ years       0.32      0.35      0.33       106
#   5-10 years       0.35      0.36      0.35       107
#     <5 years       0.38      0.46      0.42        98
#
#     accuracy                           0.33       397
#    macro avg       0.31      0.32      0.32       397
# weighted avg       0.32      0.33      0.32       397
#
# Accuracy: 0.3425692695214106
#               precision    recall  f1-score   support
#
#  10-15 years       0.23      0.17      0.20        86
#    15+ years       0.38      0.38      0.38       106
#   5-10 years       0.30      0.29      0.30       107
#     <5 years       0.40      0.51      0.45        98
#
#     accuracy                           0.34       397
#    macro avg       0.33      0.34      0.33       397
# weighted avg       0.33      0.34      0.33       397
#
# Accuracy: 0.327455919395466
#               precision    recall  f1-score   support
#
#  10-15 years       0.00      0.00      0.00        86
#    15+ years       0.30      0.40      0.34       106
#   5-10 years       0.36      0.37      0.37       107
#     <5 years       0.32      0.49      0.39        98
#
#     accuracy                           0.33       397
#    macro avg       0.25      0.31      0.28       397
# weighted avg       0.26      0.33      0.29       397
#
# Accuracy: 0.27204030226700254
#               precision    recall  f1-score   support
#
#  10-15 years       0.22      0.12      0.15        86
#    15+ years       0.26      0.45      0.33       106
#   5-10 years       0.27      0.21      0.24       107
#     <5 years       0.33      0.28      0.30        98
#
#     accuracy                           0.27       397
#    macro avg       0.27      0.26      0.26       397
# weighted avg       0.27      0.27      0.26       397
#
# Accuracy: 0.32997481108312343
#               precision    recall  f1-score   support
#
#  10-15 years       0.00      0.00      0.00        86
#    15+ years       0.31      0.43      0.36       106
#   5-10 years       0.38      0.26      0.31       107
#     <5 years       0.33      0.58      0.42        98
#
#     accuracy                           0.33       397
#    macro avg       0.25      0.32      0.27       397
# weighted avg       0.27      0.33      0.28       397
# c:\Users\wells\anaconda3\envs\bmif802\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\wells\anaconda3\envs\bmif802\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\wells\anaconda3\envs\bmif802\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\wells\anaconda3\envs\bmif802\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\wells\anaconda3\envs\bmif802\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\wells\anaconda3\envs\bmif802\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
### plot most important features

# model 1
importances1 = pd.Series(rf1.feature_importances_, index=x1_train.columns)
top_features1 = importances1.sort_values(ascending=False).head(15)

plt.figure(figsize=(8,5))
top_features1.plot(kind="bar")
plt.title("Top Feature Importances - RF1")
plt.ylabel("Importance")
plt.show()

# model 2
importances2 = pd.Series(rf2.feature_importances_, index=x2_train.columns)
top_features2 = importances2.sort_values(ascending=False).head(15)

plt.figure(figsize=(8,5))
top_features2.plot(kind="bar")
plt.title("Top Feature Importances - RF2")
plt.ylabel("Importance")
plt.show()

# model 3
importances3 = pd.Series(rf3.feature_importances_, index=x3_train.columns)
top_features3 = importances3.sort_values(ascending=False).head(15)

plt.figure(figsize=(8,5))
top_features3.plot(kind="bar")
plt.title("Top Feature Importances - RF3")
plt.ylabel("Importance")
plt.show()

# model 4
importances4 = pd.Series(rf4.feature_importances_, index=x4_train.columns)
top_features4 = importances4.sort_values(ascending=False).head(15)

plt.figure(figsize=(8,5))
top_features4.plot(kind="bar")
plt.title("Top Feature Importances - RF4")
plt.ylabel("Importance")
plt.show()
